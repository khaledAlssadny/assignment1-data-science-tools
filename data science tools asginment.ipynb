# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
file=pd.read_csv("IRIS.csv")
file
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
x = file.sepal_length
y = file.sepal_width
plt.scatter(x,y, marker='o',color='black')

# %%
x = file.petal_length
y = file.petal_width
plt.scatter(x,y, marker='o',color='yellow')

# %%
import numpy as np
import matplotlib.pyplot as plt
xlist = np.linspace(0, 5, 50)
ylist = np.linspace(0, 5, 90)
X, Y = np.meshgrid(xlist, ylist)
Z = np.cos(X*Y*100)
fig,ax=plt.subplots(1,1)
cp = ax.contourf(X, Y, Z,cmap='Greys')
fig.colorbar(cp) # Add a colorbar to a plot
ax.set_title('Gray-scaled')
ax.set_xlabel('x (cm)')
ax.set_ylabel('y (cm)')
plt.show()
fig1.savefig('contour-grey.png')
fig2,ax=plt.subplots(1,2)
ax=plt.axes(projection="3d")
ax.contour3D(X,Y,Z)
fig2.savefig('3D_plot.png')

# %%
table1 = pd.DataFrame({'name':['Mary','Jospeh'],'drink':['wine','beer']})
table2 = pd.DataFrame({'name':['Peter','Paul','Mary'],'food':['fish','beans','bread']})

# %%
table_inner = pd.merge(table1, table2, on='name', how='inner')
table_inner
# Out:
#    name drink   food
# 0  Mary  wine  bread

# %%
table_outer = pd.merge(table1, table2, on='name', how='outer')
table_outer
# Out:
#      name drink   food
# 0    Mary  wine  bread
# 1  Jospeh  beer    NaN
# 2   Peter   NaN   fish
# 3    Paul   NaN  beans
